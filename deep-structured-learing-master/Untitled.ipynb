# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# p237 데이터 로딩, p240 자동으로 컬럼 생성
df = pd.read_csv('C:\/iris.data',header=None)
df.shape, type(df)
# Out:
# ((150, 5), pandas.core.frame.DataFrame)

# %%
df.iloc[10:15,2:4] #intefer Location
# Out:
#       2    3
# 10  1.5  0.2
# 11  1.6  0.2
# 12  1.4  0.1
# 13  1.1  0.1
# 14  1.2  0.2

# %%
df.plot() #수치데이터를 그래프로 표현

# %%
df.boxplot()

# %%
#컬럼 4의 문자를 숫자로 바꿔줘야한다.
df[4].unique() # 컬럼 4만 가져오기
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.head(1)
pd.__version__
# Out:
# '0.25.0'

# %%
x = df.drop(columns=4)
y = df[4]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression() #모델 호출
model.fit(x,y) #학습시키기
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
model.score(x,y)
# Out:
# 0.96

# %%
model.coef_,model.intercept_
# Out:
# (array([[ 0.41498833,  1.46129739, -2.26214118, -1.0290951 ],
#         [ 0.41663969, -1.60083319,  0.57765763, -1.38553843],
#         [-1.70752515, -1.53426834,  2.47097168,  2.55538211]]),
#  array([ 0.26560617,  1.08542374, -1.21471458]))

# %%
#선형 모델의 원리
# y = (a * x1) + (b * x2) + (c * x3) + (d * x4) + bias
y = (0.41498833 * 5.1) + (1.46129739 * 3.5) + (2.26214118 * 1.4) + (1.0290951 * 0.2) + 0.26

# %%
np.set_printoptions(precision=3, threshold=3, suppress=True)

# %%
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
x0 = np.array(df.iloc[0, :4])
x0 = x0.astype(np.float32)

# %%
np.sum(model.coef_ * x0, axis=1) + model.intercept_
# Out:
# array([  4.124,  -1.861, -11.323])

# %%
# 토이 샘플로 선형 회귀를 이해해보자
# 키와 몸무게

# %%
x = [150,160,170,180,190]
y = [50,55,63,70,85]
x_test = [155,165,175,185,200]
x=np.array(x).reshape([-1,1])
y=np.array(y).reshape([-1,1])
x_test = np.array(x_test).reshape([-1,1])

# %%
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.figure(figsize=(3,1))
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression# dPcmr

# %%
model = LinearRegression().fit(x,y)
model.score(x,y)
# Out:
# 0.9592405735528412

# %% [markdown]
# model.coef_,model.intercept_

# %%
model.coef_,model.intercept_
# Out:
# (array([[0.85]]), array([-79.9]))

# %%
키 = np.arange(150,200)
예상몸무게 = 0.85*키-79.9
plt.figure(figsize=(3,1))
plt.scatter(키, 예상몸무게, label='predict')
plt.scatter(x,y, label='real')
plt.legend()

# %%
# [온도, 강수량]
x = [[20,0],[25,0],[30,0],[20,10],[25,15],[35,0]]
y = [5,5,4,3.5,3,2]

x = np.array(x)
y = np.array(y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x,y)
model.score(x,y)
# Out:
# 0.7711638679791547

# %%
model.coef_,model.intercept_
# Out:
# (array([-0.173, -0.118]), 8.716560509554139)

# %%
x_test = np.array([[36,15],[15,0]])
model.predict(x_test)/60
# Out:
# array([0.012, 0.102])
